# %%
import numpy as np
import pandas as pd
import random
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#generating random values based on known means and standard deviations:

#first make a dataframe:
fake_dataset = pd.DataFrame()

#because we're generating random data, we want to set the seed so if someone wanted to reproduce your results, they could:
np.random.seed(1234) #this can be any number you want

# %%
#generate age data based on a population with a mean of 35 (loc) and a standard deviation of 6 (scale).
# You'd replace the 35 and 6 with the data you collect.
#the size parameter is how many "samples" we want:
age_ranges = np.random.normal(loc=40, scale=12, size=5133)
#add the ages to your dataframe:
fake_dataset['age'] = age_ranges
#let's round the ages to the nearest year:
fake_dataset['age'] = np.round(fake_dataset['age'], 0)

# #generate dropout data based on a population with a mean of 10 (loc) and a standard deviation of 20 (scale).
# def drop():
#   dropout_ranges = np.random.normal(loc=10, scale=20, size=5133)
#   for i in dropout_ranges:
#     if i<0:
#       dropout_ranges = np.random.normal(loc=10, scale=20, size=5133)
#       drop()

# drop()
# fake_dataset['dropout'] = dropout_ranges
# fake_dataset['dropout'] = np.round(fake_dataset['dropout'], 0)

# %%
#lets assign genders to your dataset (based on US gender distributions); 0 for Male, 1 for Female
gender_rand = np.random.choice(['0', '1'], p=[0.49, 0.51], size=5133)
fake_dataset['gender'] = gender_rand

#assign treatment (placebo/medication) to dataset (based on studies); 0 for placebo, 1 for medication
# treatment_rand = np.random.choice(['0', '1'], p=[0.36, 0.64], size=5133)
# fake_dataset['treatment'] = treatment_rand

#assign medication to participants with medicaiton (based on studies); 0 for paroxetine, 1 for nefazodone, 2 for venlafaxine, 3 for fluoxetine, 4 for placebo
medication_rand = np.random.choice(['0', '1', '2', '3', '4'], p=[0.17, 0.17, 0.14, 0.16, 0.36], size=5133)
fake_dataset['medication'] = medication_rand

#assign final HAM score to participoants with different mean based on which treatment and medication they receive
final_ham_placebo = np.random.normal(loc=17.91)
final_ham_flu = np.random.normal(loc=15.64)
final_ham_ven = np.random.normal(loc=13.53)
final_ham_nefa = np.random.normal(loc=13.73)
final_ham_parox = np.random.normal(loc=16.35)
fake_dataset.loc[fake_dataset['medication']=='4', 'final_hamd_score'] = final_ham_placebo
fake_dataset.loc[fake_dataset['medication']=='0', 'final_hamd_score'] = final_ham_parox
fake_dataset.loc[fake_dataset['medication']=='1', 'final_hamd_score'] = final_ham_nefa
fake_dataset.loc[fake_dataset['medication']=='2', 'final_hamd_score'] = final_ham_ven
fake_dataset.loc[fake_dataset['medication']=='3', 'final_hamd_score'] = final_ham_flu

# %%
#for the Hamilton scores: here's where you want to make a "random/random" dataset v.s. a weighted dataset:
#Random/Random Hamilton score generator:

#Impt Qs: depressed mood, feelings of guilt, suicide, insomnia early, insomnia middle, insomnia early morn, work/activities, anxiety psychic, anxiety somatic, somatic gastroint, general somatic, hypchondira
#1, 2, 3, 4, 5, 6, 7, 10, 11, 12, 13, 15

#Weighted Qs:  depressed mood, feelings of guilt, suicide, work/activities, anxiety psychic
#1,2,3,7,10

scores = [0, 1, 2, 3, 4] #may need to asjust options depending on question you're modeling
hamilton_question1_score = random.choices(scores, k=5133)
#add probabilities (p) - more likely to score 2 or 3 than 0, 1 or 4
hamilton_question1_score_w1 = np.random.choice(scores, p=[0.10, 0.10, 0.35, 0.35, 0.10], size=5133)
#add probabilities - more likely to answer 1 or 2 vs 3 or 4 (play around with these to see which distributions make more sense)
hamilton_question1_score_w2 = np.random.choice(scores, p=[0.35, 0.35, 0.15, 0.10, 0.05], size=5133)

hamilton_question2_score = random.choices(scores, k=5133)
#add probabilities (p) - more likely to score 2 or 3 than 0, 1 or 4
hamilton_question2_score_w1 = np.random.choice(scores, p=[0.10, 0.10, 0.35, 0.35, 0.10], size=5133)
#add probabilities - more likely to answer 1 or 2 vs 3 or 4 (play around with these to see which distributions make more sense)
hamilton_question2_score_w2 = np.random.choice(scores, p=[0.35, 0.35, 0.15, 0.10, 0.05], size=5133)

hamilton_question3_score = random.choices(scores, k=5133)
#add probabilities (p) - more likely to score 2 or 3 than 0, 1 or 4
hamilton_question3_score_w1 = np.random.choice(scores, p=[0.10, 0.10, 0.35, 0.35, 0.10], size=5133)
#add probabilities - more likely to answer 1 or 2 vs 3 or 4 (play around with these to see which distributions make more sense)
hamilton_question3_score_w2 = np.random.choice(scores, p=[0.35, 0.35, 0.15, 0.10, 0.05], size=5133)

hamilton_question4_score = random.choices(scores, k=5133)
#add probabilities (p) - more likely to score 2 or 3 than 0, 1 or 4
hamilton_question4_score_w1 = np.random.choice(scores, p=[0.10, 0.10, 0.35, 0.35, 0.10], size=5133)
#add probabilities - more likely to answer 1 or 2 vs 3 or 4 (play around with these to see which distributions make more sense)
hamilton_question4_score_w2 = np.random.choice(scores, p=[0.20, 0.20, 0.20, 0.20, 0.20], size=5133)

hamilton_question5_score = random.choices(scores, k=5133)
#add probabilities (p) - more likely to score 2 or 3 than 0, 1 or 4
hamilton_question5_score_w1 = np.random.choice(scores, p=[0.10, 0.10, 0.35, 0.35, 0.10], size=5133)
#add probabilities - more likely to answer 1 or 2 vs 3 or 4 (play around with these to see which distributions make more sense)
hamilton_question5_score_w2 = np.random.choice(scores, p=[0.20, 0.20, 0.20, 0.20, 0.20], size=5133)

hamilton_question6_score = random.choices(scores, k=5133)
#add probabilities (p) - more likely to score 2 or 3 than 0, 1 or 4
hamilton_question6_score_w1 = np.random.choice(scores, p=[0.10, 0.10, 0.35, 0.35, 0.10], size=5133)
#add probabilities - more likely to answer 1 or 2 vs 3 or 4 (play around with these to see which distributions make more sense)
hamilton_question6_score_w2 = np.random.choice(scores, p=[0.20, 0.20, 0.20, 0.20, 0.20], size=5133)

hamilton_question7_score = random.choices(scores, k=5133)
#add probabilities (p) - more likely to score 2 or 3 than 0, 1 or 4
hamilton_question7_score_w1 = np.random.choice(scores, p=[0.10, 0.10, 0.35, 0.35, 0.10], size=5133)
#add probabilities - more likely to answer 1 or 2 vs 3 or 4 (play around with these to see which distributions make more sense)
hamilton_question7_score_w2 = np.random.choice(scores, p=[0.35, 0.35, 0.15, 0.10, 0.05], size=5133)

hamilton_question10_score = random.choices(scores, k=5133)
#add probabilities (p) - more likely to score 2 or 3 than 0, 1 or 4
hamilton_question10_score_w1 = np.random.choice(scores, p=[0.10, 0.10, 0.35, 0.35, 0.10], size=5133)
#add probabilities - more likely to answer 1 or 2 vs 3 or 4 (play around with these to see which distributions make more sense)
hamilton_question10_score_w2 = np.random.choice(scores, p=[0.35, 0.35, 0.15, 0.10, 0.05], size=5133)

hamilton_question11_score = random.choices(scores, k=5133)
#add probabilities (p) - more likely to score 2 or 3 than 0, 1 or 4
hamilton_question11_score_w1 = np.random.choice(scores, p=[0.10, 0.10, 0.35, 0.35, 0.10], size=5133)
#add probabilities - more likely to answer 1 or 2 vs 3 or 4 (play around with these to see which distributions make more sense)
hamilton_question11_score_w2 = np.random.choice(scores, p=[0.20, 0.20, 0.20, 0.20, 0.20], size=5133)

hamilton_question12_score = random.choices(scores, k=5133)
#add probabilities (p) - more likely to score 2 or 3 than 0, 1 or 4
hamilton_question12_score_w1 = np.random.choice(scores, p=[0.10, 0.10, 0.35, 0.35, 0.10], size=5133)
#add probabilities - more likely to answer 1 or 2 vs 3 or 4 (play around with these to see which distributions make more sense)
hamilton_question12_score_w2 = np.random.choice(scores, p=[0.20, 0.20, 0.20, 0.20, 0.20], size=5133)

hamilton_question13_score = random.choices(scores, k=5133)
#add probabilities (p) - more likely to score 2 or 3 than 0, 1 or 4
hamilton_question13_score_w1 = np.random.choice(scores, p=[0.10, 0.10, 0.35, 0.35, 0.10], size=5133)
#add probabilities - more likely to answer 1 or 2 vs 3 or 4 (play around with these to see which distributions make more sense)
hamilton_question13_score_w2 = np.random.choice(scores, p=[0.20, 0.20, 0.20, 0.20, 0.20], size=5133)

hamilton_question15_score = random.choices(scores, k=5133)
#add probabilities (p) - more likely to score 2 or 3 than 0, 1 or 4
hamilton_question15_score_w1 = np.random.choice(scores, p=[0.10, 0.10, 0.35, 0.35, 0.10], size=5133)
#add probabilities - more likely to answer 1 or 2 vs 3 or 4 (play around with these to see which distributions make more sense)
hamilton_question15_score_w2 = np.random.choice(scores, p=[0.20, 0.20, 0.20, 0.20, 0.20], size=5133)


#add to your fake dataset to be able to plot distributions:
#Impt Qs: depressed mood, feelings of guilt, suicide, insomnia early, insomnia middle, insomnia early morn, work/activities, anxiety psychic, anxiety somatic, somatic gastroint, general somatic, hypchondira
#1, 2, 3, 4, 5, 6, 7, 10, 11, 12, 13, 15

fake_dataset['ham_q1'] = hamilton_question1_score
fake_dataset['ham_q1_w1'] = hamilton_question1_score_w1
fake_dataset['ham_q1_w2'] = hamilton_question1_score_w2

fake_dataset['ham_q2'] = hamilton_question2_score
fake_dataset['ham_q2_w1'] = hamilton_question2_score_w1
fake_dataset['ham_q2_w2'] = hamilton_question2_score_w2

fake_dataset['ham_q3'] = hamilton_question3_score
fake_dataset['ham_q3_w1'] = hamilton_question3_score_w1
fake_dataset['ham_q3_w2'] = hamilton_question3_score_w2

fake_dataset['ham_q4'] = hamilton_question4_score
fake_dataset['ham_q4_w1'] = hamilton_question4_score_w1
fake_dataset['ham_q4_w2'] = hamilton_question4_score_w2

fake_dataset['ham_q5'] = hamilton_question5_score
fake_dataset['ham_q5_w1'] = hamilton_question5_score_w1
fake_dataset['ham_q5_w2'] = hamilton_question5_score_w2

fake_dataset['ham_q6'] = hamilton_question6_score
fake_dataset['ham_q6_w1'] = hamilton_question6_score_w1
fake_dataset['ham_q6_w2'] = hamilton_question6_score_w2

fake_dataset['ham_q7'] = hamilton_question7_score
fake_dataset['ham_q7_w1'] = hamilton_question7_score_w1
fake_dataset['ham_q7_w2'] = hamilton_question7_score_w2

fake_dataset['ham_q10'] = hamilton_question10_score
fake_dataset['ham_q10_w1'] = hamilton_question10_score_w1
fake_dataset['ham_q10_w2'] = hamilton_question10_score_w2

fake_dataset['ham_q11'] = hamilton_question11_score
fake_dataset['ham_q11_w1'] = hamilton_question11_score_w1
fake_dataset['ham_q11_w2'] = hamilton_question11_score_w2

fake_dataset['ham_q12'] = hamilton_question12_score
fake_dataset['ham_q12_w1'] = hamilton_question12_score_w1
fake_dataset['ham_q12_w2'] = hamilton_question12_score_w2

fake_dataset['ham_q13'] = hamilton_question13_score
fake_dataset['ham_q13_w1'] = hamilton_question13_score_w1
fake_dataset['ham_q13_w2'] = hamilton_question13_score_w2

fake_dataset['ham_q15'] = hamilton_question15_score
fake_dataset['ham_q15_w1'] = hamilton_question15_score_w1
fake_dataset['ham_q15_w2'] = hamilton_question15_score_w2

#sum up the questions per 'patient' to get their HAM-D score:
#Impt Qs: depressed mood, feelings of guilt, suicide, insomnia early, insomnia middle, insomnia early morn, work/activities, anxiety psychic, anxiety somatic, somatic gastroint, general somatic, hypchondira
#1, 2, 3, 4, 5, 6, 7, 10, 11, 12, 13, 15
hamilton_q_cols = ['ham_q1_w2', 'ham_q2_w2', 'ham_q3_w2', 'ham_q4_w2', 'ham_q5_w2', 'ham_q6_w2', 'ham_q7_w2', 'ham_q10_w2', 'ham_q11_w2', 'ham_q12_w2', 'ham_q13_w2', 'ham_q15_w2']
fake_dataset['hamd_score'] = fake_dataset[hamilton_q_cols].sum(axis=1)


print (fake_dataset['hamd_score'].mean())
# Out:
# 19.807519968829144

# %%
plt.hist([fake_dataset['ham_q1'], fake_dataset['ham_q1_w1'], fake_dataset['ham_q1_w2'],
          fake_dataset['ham_q2'], fake_dataset['ham_q2_w1'], fake_dataset['ham_q2_w2'],
          fake_dataset['ham_q3'], fake_dataset['ham_q3_w1'], fake_dataset['ham_q3_w2'],
          fake_dataset['ham_q4'], fake_dataset['ham_q4_w1'], fake_dataset['ham_q4_w2'],
          fake_dataset['ham_q5'], fake_dataset['ham_q5_w1'], fake_dataset['ham_q5_w2'],
          fake_dataset['ham_q6'], fake_dataset['ham_q6_w1'], fake_dataset['ham_q6_w2'],
          fake_dataset['ham_q7'], fake_dataset['ham_q7_w1'], fake_dataset['ham_q7_w2'],
          fake_dataset['ham_q10'], fake_dataset['ham_q10_w1'], fake_dataset['ham_q10_w2'],
          fake_dataset['ham_q11'], fake_dataset['ham_q11_w1'], fake_dataset['ham_q11_w2'],
          fake_dataset['ham_q12'], fake_dataset['ham_q12_w1'], fake_dataset['ham_q12_w2'],
          fake_dataset['ham_q13'], fake_dataset['ham_q13_w1'], fake_dataset['ham_q13_w2'],
          fake_dataset['ham_q15'], fake_dataset['ham_q15_w1'], fake_dataset['ham_q15_w2']],
         color=['wheat', 'violet', 'turquoise',
              'tomato', 'thistle', 'teal',
              'tan', 'steelblue', 'springgreen',
              'snow', 'slategrey', 'slateblue',
              'skyblue', 'silver', 'sienna',
              'seagreen', 'sandybrown', 'salmon',
              'royalblue', 'rosybrown', 'red',
              'purple', 'rebeccapurple', 'powderblue',
              'plum', 'pink', 'peru',
              'peachpuff', 'orchid', 'orange',
              'navy', 'mintcream', 'mediumpurple',
              'maroon', 'magenta', 'lime'], alpha=0.5)
# Out:
# (array([[1024.,    0.,  992.,    0.,    0., 1089.,    0., 1039.,    0.,
#           989.],
#         [ 544.,    0.,  531.,    0.,    0., 1748.,    0., 1760.,    0.,
#           550.],
#         [1788.,    0., 1804.,    0.,    0.,  783.,    0.,  508.,    0.,
#           250.],
#         [1034.,    0., 1032.,    0.,    0.,  998.,    0.,  985.,    0.,
#          1084.],
#         [ 495.,    0.,  502.,    0.,    0., 1827.,    0., 1782.,    0.,
#           527.],
#         [1862.,    0., 1752.,    0.,    0.,  776.,    0.,  499.,    0.,
#           244.],
#         [1056.,    0.,  964.,    0.,    0.,  978.,    0., 1072.,    0.,
#          1063.],
#         [ 486.,    0.,  527.,    0.,    0., 1771.,    0., 1824.,    0.,
#           525.],
#         [1797.,    0., 1784.,    0.,    0.,  781.,    0.,  508.,    0.,
#           263.],
#         [1021.,    0., 1055.,    0.,    0., 1003.,    0.,  982.,    0.,
#          1072.],
# ...

# %%
plt.show()

sns.displot(fake_dataset, x="hamd_score", hue="gender")
plt.show()

sns.displot(fake_dataset, x="hamd_score", hue="medication")
plt.show()

sns.displot(fake_dataset, x="age", hue="gender")
plt.show()

# sns.displot(fake_dataset, x="age", hue="treatment")
# plt.show()

sns.displot(fake_dataset, x="age", hue="medication")
plt.show()

# sns.displot(fake_dataset, x="dropout", hue="gender")
# plt.show()

# sns.displot(fake_dataset, x="dropout", hue="treatment")
# plt.show()

# %%
fake_dataset
# Out:
#        age gender medication  ...  ham_q15_w1  ham_q15_w2  hamd_score
# 0     46.0      0          3  ...           2           0          21
# 1     26.0      0          2  ...           1           0          13
# 2     57.0      0          0  ...           2           4          15
# 3     36.0      0          3  ...           2           2          23
# 4     31.0      0          1  ...           3           4          21
# ...    ...    ...        ...  ...         ...         ...         ...
# 5128  33.0      1          0  ...           2           1          15
# 5129  36.0      0          2  ...           3           4          30
# 5130  73.0      1          2  ...           4           4          27
# 5131  29.0      0          4  ...           3           4          21
# 5132  33.0      0          4  ...           3           4          17
#
# [5133 rows x 41 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')

fake_dataset.to_csv('fake_dataset2.csv')
# !cp fake_dataset2.csv "drive/My Drive"
# Out:
# Mounted at /content/drive
